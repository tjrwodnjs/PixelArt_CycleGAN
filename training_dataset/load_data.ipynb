# %%
import numpy as np
import matplotlib.pyplot as plt

dataset_A = np.load('./Domain_A_50_256x256.npy')
dataset_B = np.load('./Domain_B_50_256x256.npy')

# %%
for i in range(5):
    plt.imshow(dataset_A[i])
    plt.show()

# %%
for i in range(5):
    plt.imshow(dataset_B[i])
    plt.show()
